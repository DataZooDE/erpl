# %%
from sqlalchemy import create_engine

# %load_ext sql
engine = create_engine('duckdb:///:memory:', connect_args={'config': { 'allow_unsigned_extensions': 'true' }})
# %sql engine

# %%
# %%sql
# INSTALL '../build/release/extension/erpel/erpel.duckdb_extension';
# LOAD '../build/release/extension/erpel/erpel.duckdb_extension';
#
# SET sap_ashost TO 'vhcalnplci';
# SET sap_sysnr='00';
# SET sap_user='DEVELOPER';
# SET sap_password='Bym38tpl';
# SET sap_client='001';
# SET sap_lang='EN';
# Out:
# Running query in 'duckdb:///:memory:'
# +---------+
# | Success |
# +---------+
# +---------+

# %%
# %sql select LIST_VALUE()
# Out:
# Running query in 'duckdb:///:memory:'
# +--------------+
# | list_value() |
# +--------------+
# |      []      |
# +--------------+

# %%
# %load /tmp/meta.sql
SELECT STRUCT_PACK(CHARACTERISTICS := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCPP', ALTERNATIVE_NAME := '', ID := 525, TEXT := 'Product', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPP', BASE_CHARACTERISTIC_ID := 525, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCPG', ALTERNATIVE_NAME := '', ID := 526, TEXT := 'Product Group', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPG', BASE_CHARACTERISTIC_ID := 526, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0TSC0OCPL', ALTERNATIVE_NAME := '', ID := 527, TEXT := 'Product Line', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPL', BASE_CHARACTERISTIC_ID := 527, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0TSC0OCUR', ALTERNATIVE_NAME := '', ID := 545, TEXT := 'Currency Key', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := '', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CURRENCY', BASE_CHARACTERISTIC_ID := 7, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0TSC0OKPR', ALTERNATIVE_NAME := '', ID := 563, TEXT := 'Price', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'P', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM2', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0TSC0OCPG', ALTERNATIVE_NAME := '', ID := 526, TEXT := 'Product Group', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPG', BASE_CHARACTERISTIC_ID := 526, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCPL', ALTERNATIVE_NAME := '', ID := 527, TEXT := 'Product Line', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPL', BASE_CHARACTERISTIC_ID := 527, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM2', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0TSC0OCCO', ALTERNATIVE_NAME := '', ID := 528, TEXT := 'Country', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCCO', BASE_CHARACTERISTIC_ID := 528, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := '', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM1', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0TSC0OCBK', ALTERNATIVE_NAME := '', ID := 535, TEXT := 'Company Code', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCBK', BASE_CHARACTERISTIC_ID := 535, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := '', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCUR', ALTERNATIVE_NAME := '', ID := 545, TEXT := 'Currency Key', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := '', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CURRENCY', BASE_CHARACTERISTIC_ID := 7, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM1', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0CALYEAR', ALTERNATIVE_NAME := '', ID := 15, TEXT := 'Calendar Year', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALYEAR', BASE_CHARACTERISTIC_ID := 15, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0DATEFROM', ALTERNATIVE_NAME := '', ID := 177, TEXT := 'Valid from', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0DATETO', ALTERNATIVE_NAME := '', ID := 178, TEXT := 'Valid to', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMDAY', ALTERNATIVE_NAME := '', ID := 653, TEXT := 'Number of Days', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMWDAY', ALTERNATIVE_NAME := '', ID := 654, TEXT := 'Number of Workdays', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEMT', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0CALMONTH', ALTERNATIVE_NAME := '', ID := 10, TEXT := 'Calendar Year/Month', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := 'X', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALMONTH', BASE_CHARACTERISTIC_ID := 10, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0CALMONTH2', ALTERNATIVE_NAME := '', ID := 11, TEXT := 'Calendar month', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := 'X', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALMONTH2', BASE_CHARACTERISTIC_ID := 11, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0CALYEAR', ALTERNATIVE_NAME := '', ID := 15, TEXT := 'Calendar Year', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALYEAR', BASE_CHARACTERISTIC_ID := 15, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0DATEFROM', ALTERNATIVE_NAME := '', ID := 177, TEXT := 'Valid from', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0DATETO', ALTERNATIVE_NAME := '', ID := 178, TEXT := 'Valid to', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMDAY', ALTERNATIVE_NAME := '', ID := 653, TEXT := 'Number of Days', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMWDAY', ALTERNATIVE_NAME := '', ID := 654, TEXT := 'Number of Workdays', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEMT', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0MEASURES0000000000000009', ALTERNATIVE_NAME := '', ID := 2000000908, TEXT := 'Key Figures', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := 'X', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := '', INTTP := '', DEFAULT_MEMBER_ACCESS_MODE := '', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := 'X', SUPPORTS_AGGREGATION := '', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := '', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(), IS_STRUCTURE := 'X', STRUCTURE_MEMBERS := LIST_VALUE(STRUCT_PACK(ID := 1, NAME := '0TSC0OKAC0000000000000009', ALTERNATIVE_NAME := '0TSC0OKAC', TEXT := 'Amount (EUR)', STATIC := 'X', PARENT_ID := 0, INITIAL_DRILLSTATE := 0, LEVEL := 0, MEMBER_POSITION := 1, BASED_ON_TLOGO := 'IOBJ', BASED_ON_NAME := '0TSC0OKAC', BASED_ON_TEXT := 'Amount (EUR)', STRUCTURE_ID := 0, ELTSID := 0, ELTUID := '', ALLOWED_CHANM_ID := LIST_VALUE(), ELTUID_ORG := '')), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := '', DIMENSION := '', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := '', NEW_LINE_ACCESS_MODES := LIST_VALUE(), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := 'M', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE(1)))), STRUCTURE_INFO := STRUCT_PACK(STRUCTURE_COUNT := 0, NAME_1 := '', ID_1 := 0, NAME_2 := '', ID_2 := 0), SELECTION_SPACE := LIST_VALUE(), VARIABLE_VALUES := LIST_VALUE(), QUERY_STATE := STRUCT_PACK(CHARACTERISTICS := LIST_VALUE(STRUCT_PACK(ID := 525, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 563, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 545, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 527, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 526, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(526, 527, 545, 563), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 526, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 527, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(527), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 528, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 535, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 545, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(545), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 15, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 654, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 653, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 178, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 177, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(653, 654, 177, 178), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'K', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 10, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 654, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 653, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 178, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 177, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 15, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 11, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(15, 11, 653, 654, 177, 178), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'K', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 2000000908, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', ATTRIBUTES := LIST_VALUE(), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := 'M', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE(1)), RESULT_VISIBILITY := '', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE(1)), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := 'X', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(STRUCT_PACK(ID := 1, IN_SELECTION := '', START_LIST_DRILL_STATE := 0, DISPLAY_LEVEL := 0, HAS_ACTIVE_CHILDREN := '', LOCAL_FORMULA := LIST_VALUE(), STRUCTURE_ID := 0, ELTSID := 0, ELTUID := '', ALLOWED_CHANM_ID := LIST_VALUE(), RESTRICTED_KF_ID := '')), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := '')), SELECTION_STATE := LIST_VALUE(STRUCT_PACK(NAME := '0CALMONTH', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0CALYEAR', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0MEASURES0000000000000009', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCBK', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCCO', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCPG', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCPP', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0)), FREE_AXIS := STRUCT_PACK(RESULT_ALIGNMENT := '', HIERARCHICAL := '', INITIAL_LOAD_LEVEL := 0, ZERO_SUPPRESSION := '', CHARACTERISTICS := LIST_VALUE(525, 526, 528, 535, 15, 10), ZERO_SUPPRESSION_MODE := ''), COLUMNS_AXIS := STRUCT_PACK(RESULT_ALIGNMENT := '1', HIERARCHICAL := '', INITIAL_LOAD_LEVEL := 0, ZERO_SUPPRESSION := '', CHARACTERISTICS := LIST_VALUE(2000000908), ZERO_SUPPRESSION_MODE := 'NONE'), ROWS_AXIS := STRUCT_PACK(RESULT_ALIGNMENT := '1', HIERARCHICAL := '', INITIAL_LOAD_LEVEL := 0, ZERO_SUPPRESSION := '', CHARACTERISTICS := LIST_VALUE(), ZERO_SUPPRESSION_MODE := 'NONE'), CONDITIONS := LIST_VALUE(), QUERY_PROPERTIES := STRUCT_PACK(SRDATE := '1970-01-01'::DATE, CTART := '0', TCUR := '', CTTNM := '', INPUT_ENABLED := '', DRAG_RELATE_URLS := '', ZERO_PRESENTATION := 'NORMAL', ZERO_PRESENTATION_CUST_STRING := NULL, SIGN_PRESENTATION := '1', CURRENCY_UNIT_PRESENTATION := '', RESULT_SET_SIZE_LIMIT := 0, READ_CHILD_KIDS := 'X'), DATA_CELLS := LIST_VALUE(STRUCT_PACK(ID := 1, NUM_PREC := '', NUM_SCALE := '', SIGN_INVERSION := '', CUMULATION := '', EMPHASIZED := '', DETAIL_CALCULATION := '', CALCULATION_DIRECTION := 'DEFAULT', RESULT_CALCULATION := '00', APPLY_DETAIL_CALC_TO_RESULTS := 'X', DISAGGR_KID := 0, DISAGGR_MODE := '0', NUM_PREC_02 := '99')), CONDITIONS_CONS := LIST_VALUE(), EXCEPTIONS_CONS := LIST_VALUE(), DRILL_GROUPS := LIST_VALUE(STRUCT_PACK(ID := 2000000320, NAME := '1DG_1', CHARACTERISTICS := LIST_VALUE(2000000908), START_DRILL_LEVEL := -1, NODE_ALIGNMENT := '2', ACTIVE := '', CHANGEABLE := '', AXIS := 'X'), STRUCT_PACK(ID := 2000000321, NAME := '1DG_2', CHARACTERISTICS := LIST_VALUE(), START_DRILL_LEVEL := -1, NODE_ALIGNMENT := '2', ACTIVE := '', CHANGEABLE := '', AXIS := 'Y'))), QUERY_PROPERTIES := STRUCT_PACK(COMPUID := '!!AZADEM', OBJVERS := 'A', INFOCUBE := 'ZADEM', GENUNIID := '0H1UU854Y2NTXT957MXX0PD6I', COMPTYPE := 'REP', COMPID := '!!AZADEM', CURKZ := '', PERIV := '', DUEDATE := '2023-07-25'::DATE, INPUT_MODE := '7', INFOPROVIDER_NAME := 'ZADEM', INFOPROVIDER_TEXT := 'DEMOCUBEADEM', BASE_INFOPROVIDER_NAME := '', BASE_INFOPROVIDER_TEXT := '', QUERY_NAME := '!!AZADEM', QUERY_TEXT := 'DEMOCUBEADEM', QUERY_TRANSIENT := '', QUERY_CREATED_BY := '', QUERY_CREATION_DATE := '2023-07-01'::DATE, QUERY_CREATION_TIME := '07:43:33'::TIME, QUERY_CHANGED_BY := 'DEVELOPER', QUERY_CHANGE_DATE := '2023-07-01'::DATE, QUERY_CHANGE_TIME := '07:43:33'::TIME, DATA_REFRESH_DATE := '2023-07-25'::DATE, DATA_REFRESH_TIME := '14:38:54'::TIME, DATA_ROLLUP_DATE := '2023-07-01'::DATE, DATA_ROLLUP_TIME := '08:22:33'::TIME, DATA_ROLLUP_DATE_MAX := '2023-07-01'::DATE, DATA_ROLLUP_TIME_MAX := '08:22:33'::TIME, MDX_ENABLED := '', HIDE_REPEATED_KEY_VALUES := '', NEW_LINES_ON_ANY_LEVEL := '', DISAGGREGATE_WITHOUT_DATA := ''), DATA_CELLS := LIST_VALUE(STRUCT_PACK(ID := 1, STRUCTURE_MEMBER_ID_1 := 1, STRUCTURE_MEMBER_ID_2 := 0, STRUCTURE_MEMBER_NAME_1 := '0TSC0OKAC0000000000000009', STRUCTURE_MEMBER_NAME_2 := '', STRUCTURE_MEMBER_ALT_NAME_1 := '', STRUCTURE_MEMBER_ALT_NAME_2 := '', STATIC := 'X', DFLT_PREC := '2', DFLT_SCALE := '0', SIGNINV := '', TCUR := '', SUMABLE := 'X', INPUT_ENABLED := '', MWKZ := 'W', AGGREGATION := 'SUM', EMPHASIZED := '', DISAGGR_KID := 0, DISAGGR_MODE := '0', BASED_ON_CHANMID := 0, BASED_ON_CHANM := '', BASED_ON_CHA_F4_SUPPORT := '', WITH_CALCULATION := '', RESULT_CALCULATION := '00', SINGLE_VALUE_CALCULATION := '', CUMULATION := '', HIDDEN := '', LOCAL_FORMULA := '', HAS_NO_CHECK_TABLE := '')), DEFAULT_VIEW_DEFINITION := '<?xml version=\x221.0\x22 encoding=\x22utf-8\x22?><BICS_VIEW><IS_INPUT_ENABLED>true</IS_INPUT_ENABLED><VARIABLES/><CHARACTERISTICS><CHARACTERISTIC name=\x220CALMONTH\x22><ATTRIBUTES><ATTRIBUTE name=\x220CALMONTH2\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220CALYEAR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220DATEFROM\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220DATETO\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMWDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0CALYEAR</ATTRIBUTE><ATTRIBUTE>0CALMONTH2</ATTRIBUTE><ATTRIBUTE>0NUMDAY</ATTRIBUTE><ATTRIBUTE>0NUMWDAY</ATTRIBUTE><ATTRIBUTE>0DATEFROM</ATTRIBUTE><ATTRIBUTE>0DATETO</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220CALYEAR\x22><ATTRIBUTES><ATTRIBUTE name=\x220DATEFROM\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220DATETO\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMWDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0NUMDAY</ATTRIBUTE><ATTRIBUTE>0NUMWDAY</ATTRIBUTE><ATTRIBUTE>0DATEFROM</ATTRIBUTE><ATTRIBUTE>0DATETO</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCBK\x22><ATTRIBUTES><ATTRIBUTE name=\x220TSC0OCUR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0TSC0OCUR</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCCO\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCPG\x22><ATTRIBUTES><ATTRIBUTE name=\x220TSC0OCPL\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0TSC0OCPL</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCPP\x22><ATTRIBUTES><ATTRIBUTE name=\x220TSC0OCPG\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220TSC0OCPL\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220TSC0OCUR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220TSC0OKPR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0TSC0OCPG</ATTRIBUTE><ATTRIBUTE>0TSC0OCPL</ATTRIBUTE><ATTRIBUTE>0TSC0OCUR</ATTRIBUTE><ATTRIBUTE>0TSC0OKPR</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220MEASURES0000000000000009\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC></CHARACTERISTICS><AXES><AXIS name=\x22COLUMNS\x22><HIERARCHY><DRILL_LEVEL>00</DRILL_LEVEL></HIERARCHY><ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS>true</ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS><CHARACTERISTICS><CHARACTERISTIC>0MEASURES0000000000000009</CHARACTERISTIC></CHARACTERISTICS></AXIS><AXIS name=\x22ROWS\x22><HIERARCHY><DRILL_LEVEL>00</DRILL_LEVEL></HIERARCHY><ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS>true</ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS><CHARACTERISTICS/></AXIS></AXES><DATA_CELLS><DATA_CELL><MEMBERS><MEMBER name=\x220TSC0OKAC0000000000000009\x22 characteristic=\x220MEASURES0000000000000009\x22/></MEMBERS><APPLY_DETAIL_CALCULATION_TO_RESULTS>true</APPLY_DETAIL_CALCULATION_TO_RESULTS></DATA_CELL></DATA_CELLS><DRILL_OPERATIONS/><CONDITIONS/><EXCEPTIONS/></BICS_VIEW>'::BLOB, DESIGNTIME_INFO := STRUCT_PACK(QUERY_NAME := '', SELECTION_SPACE := LIST_VALUE(), SELECTION_STATE := LIST_VALUE(), VARIABLES := LIST_VALUE(), VARIABLE_CHARACTERISTICS_META := LIST_VALUE(), VARIABLE_CHARACTERISTICS_STATE := LIST_VALUE(), KEY_FIGURES := LIST_VALUE(), NODE_TYPES := LIST_VALUE(), HIERARCHIES := LIST_VALUE(), CHARACTERISTICS := LIST_VALUE(), SELECTION_STATE_SORTING := LIST_VALUE(), DATACELL_DETAILS := LIST_VALUE()), DIMENSIONS := LIST_VALUE(STRUCT_PACK(NAME := 'ZADEMP', TEXT := 'Data Package'), STRUCT_PACK(NAME := 'ZADEMT', TEXT := 'Time'), STRUCT_PACK(NAME := 'ZADEM1', TEXT := 'Organization'), STRUCT_PACK(NAME := 'ZADEM2', TEXT := 'Product'))) as X

# %%
from sqlalchemy import text

with engine.connect() as con:
    result = con.execute(text("SELECT STRUCT_PACK(CHARACTERISTICS := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCPP', ALTERNATIVE_NAME := '', ID := 525, TEXT := 'Product', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPP', BASE_CHARACTERISTIC_ID := 525, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCPG', ALTERNATIVE_NAME := '', ID := 526, TEXT := 'Product Group', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPG', BASE_CHARACTERISTIC_ID := 526, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0TSC0OCPL', ALTERNATIVE_NAME := '', ID := 527, TEXT := 'Product Line', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPL', BASE_CHARACTERISTIC_ID := 527, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0TSC0OCUR', ALTERNATIVE_NAME := '', ID := 545, TEXT := 'Currency Key', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := '', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CURRENCY', BASE_CHARACTERISTIC_ID := 7, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0TSC0OKPR', ALTERNATIVE_NAME := '', ID := 563, TEXT := 'Price', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'P', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM2', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0TSC0OCPG', ALTERNATIVE_NAME := '', ID := 526, TEXT := 'Product Group', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPG', BASE_CHARACTERISTIC_ID := 526, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCPL', ALTERNATIVE_NAME := '', ID := 527, TEXT := 'Product Line', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCPL', BASE_CHARACTERISTIC_ID := 527, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM2', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0TSC0OCCO', ALTERNATIVE_NAME := '', ID := 528, TEXT := 'Country', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCCO', BASE_CHARACTERISTIC_ID := 528, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := '', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM1', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0TSC0OCBK', ALTERNATIVE_NAME := '', ID := 535, TEXT := 'Company Code', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0TSC0OCBK', BASE_CHARACTERISTIC_ID := 535, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := '', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0TSC0OCUR', ALTERNATIVE_NAME := '', ID := 545, TEXT := 'Currency Key', HAS_SHORT_TEXT := 'X', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := '', INTTP := 'C', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CURRENCY', BASE_CHARACTERISTIC_ID := 7, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEM1', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0CALYEAR', ALTERNATIVE_NAME := '', ID := 15, TEXT := 'Calendar Year', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALYEAR', BASE_CHARACTERISTIC_ID := 15, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0DATEFROM', ALTERNATIVE_NAME := '', ID := 177, TEXT := 'Valid from', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0DATETO', ALTERNATIVE_NAME := '', ID := 178, TEXT := 'Valid to', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMDAY', ALTERNATIVE_NAME := '', ID := 653, TEXT := 'Number of Days', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMWDAY', ALTERNATIVE_NAME := '', ID := 654, TEXT := 'Number of Workdays', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEMT', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0CALMONTH', ALTERNATIVE_NAME := '', ID := 10, TEXT := 'Calendar Year/Month', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := 'X', HAS_TEXT := 'X', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'Q', DEFAULT_MEMBER_ACCESS_MODE_DT := 'D', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALMONTH', BASE_CHARACTERISTIC_ID := 10, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'Q', TEXT := 'Only values with booked data in current navigational state', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := 'Master Data tables', FUZZY_SEARCH := ''), STRUCT_PACK(READ_MODE := 'D', TEXT := 'Only values posted to dimension of Basic InfoCube(s)', FUZZY_SEARCH := '')), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := '', SUPPORTS_AGGREGATION := 'X', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := 'X', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(NAME := '0CALMONTH2', ALTERNATIVE_NAME := '', ID := 11, TEXT := 'Calendar month', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := 'X', HAS_LONG_TEXT := 'X', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALMONTH2', BASE_CHARACTERISTIC_ID := 11, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0CALYEAR', ALTERNATIVE_NAME := '', ID := 15, TEXT := 'Calendar Year', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'N', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0CALYEAR', BASE_CHARACTERISTIC_ID := 15, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0DATEFROM', ALTERNATIVE_NAME := '', ID := 177, TEXT := 'Valid from', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0DATETO', ALTERNATIVE_NAME := '', ID := 178, TEXT := 'Valid to', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'D', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '0DATE', BASE_CHARACTERISTIC_ID := 16, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMDAY', ALTERNATIVE_NAME := '', ID := 653, TEXT := 'Number of Days', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := ''), STRUCT_PACK(NAME := '0NUMWDAY', ALTERNATIVE_NAME := '', ID := 654, TEXT := 'Number of Workdays', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := '', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := 'X', INTTP := 'I', DEFAULT_MEMBER_ACCESS_MODE := 'M', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), SUPPORTS_MEMBER_ACCESS := '')), IS_STRUCTURE := '', STRUCTURE_MEMBERS := LIST_VALUE(), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := 'X', DIMENSION := 'ZADEMT', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := 'M', NEW_LINE_ACCESS_MODES := LIST_VALUE(STRUCT_PACK(READ_MODE := 'M', TEXT := '', FUZZY_SEARCH := '')), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(NAME := '0MEASURES0000000000000009', ALTERNATIVE_NAME := '', ID := 2000000908, TEXT := 'Key Figures', HAS_SHORT_TEXT := '', HAS_MEDIUM_TEXT := '', HAS_LONG_TEXT := 'X', HAS_TEXT := '', SUPPORTS_LOWERCASE_KEYS := '', HAS_COMPOUNDMENT := '', COMPOUNDMENT_KEY_OFFSET := 0, HAS_CONV_EXIT := '', INTTP := '', DEFAULT_MEMBER_ACCESS_MODE := '', DEFAULT_MEMBER_ACCESS_MODE_DT := '', IS_DOCUMENT_RELEVANT := '', BASE_CHARACTERISTIC := '', BASE_CHARACTERISTIC_ID := 0, DEFAULT_SELECTOR_PRSNT := '', SELECTION_MODE := '', BO_NAME := NULL, BO_NAMESPACE := NULL, BON_NAME := NULL, BON_NAMESPACE := NULL, BON_CCTS_NAME := NULL, BON_CCTS_NAMESPACE := NULL, OBN_SYSTEM_ALIAS := '', DEFAULT_VISUALIZATION_LEVEL := '', SUPPORTED_MEMBER_ACCESS_MODES := LIST_VALUE(), SUPPORTED_MEMBER_ACC_MODES_DT := LIST_VALUE(), USED_FOR_NAVIGATION := 'X', USED_FOR_SELECTION_SPACE := '', USED_FOR_DATA_CELL_DEFINITION := '', CONTAINS_KEYFIGURES := 'X', SUPPORTS_AGGREGATION := '', SUPPORTS_SELECTION := 'X', GIS_TYPE := '0', GIS_ATTRIBUTE_NAME := '', BOR_OBJTYP := '', SUPPORTS_HIERARCHIES := '', SUPPORTS_SORT_BY_SELECT_SPACE := '', ATTRIBUTES := LIST_VALUE(), IS_STRUCTURE := 'X', STRUCTURE_MEMBERS := LIST_VALUE(STRUCT_PACK(ID := 1, NAME := '0TSC0OKAC0000000000000009', ALTERNATIVE_NAME := '0TSC0OKAC', TEXT := 'Amount (EUR)', STATIC := 'X', PARENT_ID := 0, INITIAL_DRILLSTATE := 0, LEVEL := 0, MEMBER_POSITION := 1, BASED_ON_TLOGO := 'IOBJ', BASED_ON_NAME := '0TSC0OKAC', BASED_ON_TEXT := 'Amount (EUR)', STRUCTURE_ID := 0, ELTSID := 0, ELTUID := '', ALLOWED_CHANM_ID := LIST_VALUE(), ELTUID_ORG := '')), RS_ACCESS_MODES := LIST_VALUE(), DEFAULT_RS_ACCESS_MODE := '0', IS_SUMMABLE := '', DIMENSION := '', ARTIFICIAL_INFOOBJECT := '', NO_MASTER_DATA := '', DEFAULT_NEW_LINE_ACCESS_MODE := '', NEW_LINE_ACCESS_MODES := LIST_VALUE(), INIVIEW_PRIO := '', DEFAULT_SORTING := STRUCT_PACK(TYPE := 'M', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE(1)))), STRUCTURE_INFO := STRUCT_PACK(STRUCTURE_COUNT := 0, NAME_1 := '', ID_1 := 0, NAME_2 := '', ID_2 := 0), SELECTION_SPACE := LIST_VALUE(), VARIABLE_VALUES := LIST_VALUE(), QUERY_STATE := STRUCT_PACK(CHARACTERISTICS := LIST_VALUE(STRUCT_PACK(ID := 525, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 563, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 545, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 527, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 526, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(526, 527, 545, 563), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 526, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 527, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(527), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 528, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 535, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 545, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(545), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 15, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 654, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 653, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 178, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 177, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(653, 654, 177, 178), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'K', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 10, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := 'Q', ATTRIBUTES := LIST_VALUE(STRUCT_PACK(ID := 654, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 653, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 178, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 177, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 15, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE())), STRUCT_PACK(ID := 11, RESULT_SET_PRESENTATION := 4, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 4, MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()))), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), RESULT_VISIBILITY := 'C', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(15, 11, 653, 654, 177, 178), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'K', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := '', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := ''), STRUCT_PACK(ID := 2000000908, RESULT_SET_PRESENTATION := 32, MEMBER_ACCESS_INDIV_SETTINGS := '', MEMBER_ACCESS_PRESENTATION := 32, MEMBER_ACCESS_MODE := '', ATTRIBUTES := LIST_VALUE(), RESULT_SET_ATTRIBUTES := LIST_VALUE(), RESULT_SET_SORTING := STRUCT_PACK(TYPE := 'M', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE(1)), RESULT_VISIBILITY := '', MEMBER_ACCESS_ATTRIBUTES := LIST_VALUE(), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := 'T', DIRECTION := 'A', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE(1)), STRUCTURE_HRY_DRILL_LEVEL := 0, STRUCTURE_HRY_NODE_ALIGNMENT := '', STRUCTURE_GROUPS_TUPLES := 'X', RESULT_ACCESS_MODE := '0', RESULT_FULFILL_COND_VISIBLE := '', RESULT_VIOLATE_COND_VISIBLE := '', STRUCTURE_MEMBERS := LIST_VALUE(STRUCT_PACK(ID := 1, IN_SELECTION := '', START_LIST_DRILL_STATE := 0, DISPLAY_LEVEL := 0, HAS_ACTIVE_CHILDREN := '', LOCAL_FORMULA := LIST_VALUE(), STRUCTURE_ID := 0, ELTSID := 0, ELTUID := '', ALLOWED_CHANM_ID := LIST_VALUE(), RESTRICTED_KF_ID := '')), HIERARCHY_NAME := '', HIERARCHY_VERSION := '', HIERARCHY_DUEDATE := '1970-01-01'::DATE, HIERARCHY_STATE := STRUCT_PACK(ID := 0, ACTIVE := '', START_DRILL_LEVEL := 0, NODE_ALIGNMENT := '', NODE_VISIBILITY := '', MEMBER_ACCESS_MODE := '', MEMBER_ACCESS_MODES := LIST_VALUE(), ALEAFNODSP := '', RESULT_SET_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), MEMBER_ACCESS_SORTING := STRUCT_PACK(TYPE := '', DIRECTION := '', ATTRIBUTE_ID := 0, DATA_CELL_ID := 0, PREDEFINED_MEMBERS_ORDER := LIST_VALUE()), NODE_TYPES := LIST_VALUE()), CUMULATION := '')), SELECTION_STATE := LIST_VALUE(STRUCT_PACK(NAME := '0CALMONTH', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0CALYEAR', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0MEASURES0000000000000009', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCBK', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCCO', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCPG', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0), STRUCT_PACK(NAME := '0TSC0OCPP', SELECTION := LIST_VALUE(), IS_SINGLE_VALUE_SEL := 0, IS_SELECTION_INCLUDED := '', SELECTION_LINE_COUNT := 0)), FREE_AXIS := STRUCT_PACK(RESULT_ALIGNMENT := '', HIERARCHICAL := '', INITIAL_LOAD_LEVEL := 0, ZERO_SUPPRESSION := '', CHARACTERISTICS := LIST_VALUE(525, 526, 528, 535, 15, 10), ZERO_SUPPRESSION_MODE := ''), COLUMNS_AXIS := STRUCT_PACK(RESULT_ALIGNMENT := '1', HIERARCHICAL := '', INITIAL_LOAD_LEVEL := 0, ZERO_SUPPRESSION := '', CHARACTERISTICS := LIST_VALUE(2000000908), ZERO_SUPPRESSION_MODE := 'NONE'), ROWS_AXIS := STRUCT_PACK(RESULT_ALIGNMENT := '1', HIERARCHICAL := '', INITIAL_LOAD_LEVEL := 0, ZERO_SUPPRESSION := '', CHARACTERISTICS := LIST_VALUE(), ZERO_SUPPRESSION_MODE := 'NONE'), CONDITIONS := LIST_VALUE(), QUERY_PROPERTIES := STRUCT_PACK(SRDATE := '1970-01-01'::DATE, CTART := '0', TCUR := '', CTTNM := '', INPUT_ENABLED := '', DRAG_RELATE_URLS := '', ZERO_PRESENTATION := 'NORMAL', ZERO_PRESENTATION_CUST_STRING := NULL, SIGN_PRESENTATION := '1', CURRENCY_UNIT_PRESENTATION := '', RESULT_SET_SIZE_LIMIT := 0, READ_CHILD_KIDS := 'X'), DATA_CELLS := LIST_VALUE(STRUCT_PACK(ID := 1, NUM_PREC := '', NUM_SCALE := '', SIGN_INVERSION := '', CUMULATION := '', EMPHASIZED := '', DETAIL_CALCULATION := '', CALCULATION_DIRECTION := 'DEFAULT', RESULT_CALCULATION := '00', APPLY_DETAIL_CALC_TO_RESULTS := 'X', DISAGGR_KID := 0, DISAGGR_MODE := '0', NUM_PREC_02 := '99')), CONDITIONS_CONS := LIST_VALUE(), EXCEPTIONS_CONS := LIST_VALUE(), DRILL_GROUPS := LIST_VALUE(STRUCT_PACK(ID := 2000000320, NAME := '1DG_1', CHARACTERISTICS := LIST_VALUE(2000000908), START_DRILL_LEVEL := -1, NODE_ALIGNMENT := '2', ACTIVE := '', CHANGEABLE := '', AXIS := 'X'), STRUCT_PACK(ID := 2000000321, NAME := '1DG_2', CHARACTERISTICS := LIST_VALUE(), START_DRILL_LEVEL := -1, NODE_ALIGNMENT := '2', ACTIVE := '', CHANGEABLE := '', AXIS := 'Y'))), QUERY_PROPERTIES := STRUCT_PACK(COMPUID := '!!AZADEM', OBJVERS := 'A', INFOCUBE := 'ZADEM', GENUNIID := '0H1UU854Y2NTXT957MXX0PD6I', COMPTYPE := 'REP', COMPID := '!!AZADEM', CURKZ := '', PERIV := '', DUEDATE := '2023-07-25'::DATE, INPUT_MODE := '7', INFOPROVIDER_NAME := 'ZADEM', INFOPROVIDER_TEXT := 'DEMOCUBEADEM', BASE_INFOPROVIDER_NAME := '', BASE_INFOPROVIDER_TEXT := '', QUERY_NAME := '!!AZADEM', QUERY_TEXT := 'DEMOCUBEADEM', QUERY_TRANSIENT := '', QUERY_CREATED_BY := '', QUERY_CREATION_DATE := '2023-07-01'::DATE, QUERY_CREATION_TIME := '07:43:33'::TIME, QUERY_CHANGED_BY := 'DEVELOPER', QUERY_CHANGE_DATE := '2023-07-01'::DATE, QUERY_CHANGE_TIME := '07:43:33'::TIME, DATA_REFRESH_DATE := '2023-07-25'::DATE, DATA_REFRESH_TIME := '14:53:32'::TIME, DATA_ROLLUP_DATE := '2023-07-01'::DATE, DATA_ROLLUP_TIME := '08:22:33'::TIME, DATA_ROLLUP_DATE_MAX := '2023-07-01'::DATE, DATA_ROLLUP_TIME_MAX := '08:22:33'::TIME, MDX_ENABLED := '', HIDE_REPEATED_KEY_VALUES := '', NEW_LINES_ON_ANY_LEVEL := '', DISAGGREGATE_WITHOUT_DATA := ''), DATA_CELLS := LIST_VALUE(STRUCT_PACK(ID := 1, STRUCTURE_MEMBER_ID_1 := 1, STRUCTURE_MEMBER_ID_2 := 0, STRUCTURE_MEMBER_NAME_1 := '0TSC0OKAC0000000000000009', STRUCTURE_MEMBER_NAME_2 := '', STRUCTURE_MEMBER_ALT_NAME_1 := '', STRUCTURE_MEMBER_ALT_NAME_2 := '', STATIC := 'X', DFLT_PREC := '2', DFLT_SCALE := '0', SIGNINV := '', TCUR := '', SUMABLE := 'X', INPUT_ENABLED := '', MWKZ := 'W', AGGREGATION := 'SUM', EMPHASIZED := '', DISAGGR_KID := 0, DISAGGR_MODE := '0', BASED_ON_CHANMID := 0, BASED_ON_CHANM := '', BASED_ON_CHA_F4_SUPPORT := '', WITH_CALCULATION := '', RESULT_CALCULATION := '00', SINGLE_VALUE_CALCULATION := '', CUMULATION := '', HIDDEN := '', LOCAL_FORMULA := '', HAS_NO_CHECK_TABLE := '')), DEFAULT_VIEW_DEFINITION := '<?xml version=\x221.0\x22 encoding=\x22utf-8\x22?><BICS_VIEW><IS_INPUT_ENABLED>true</IS_INPUT_ENABLED><VARIABLES/><CHARACTERISTICS><CHARACTERISTIC name=\x220CALMONTH\x22><ATTRIBUTES><ATTRIBUTE name=\x220CALMONTH2\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220CALYEAR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220DATEFROM\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220DATETO\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMWDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0CALYEAR</ATTRIBUTE><ATTRIBUTE>0CALMONTH2</ATTRIBUTE><ATTRIBUTE>0NUMDAY</ATTRIBUTE><ATTRIBUTE>0NUMWDAY</ATTRIBUTE><ATTRIBUTE>0DATEFROM</ATTRIBUTE><ATTRIBUTE>0DATETO</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220CALYEAR\x22><ATTRIBUTES><ATTRIBUTE name=\x220DATEFROM\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220DATETO\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220NUMWDAY\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0NUMDAY</ATTRIBUTE><ATTRIBUTE>0NUMWDAY</ATTRIBUTE><ATTRIBUTE>0DATEFROM</ATTRIBUTE><ATTRIBUTE>0DATETO</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22MEMBERS\x22><PRESENTATION>DISPLAY_KEY</PRESENTATION></SORTING></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCBK\x22><ATTRIBUTES><ATTRIBUTE name=\x220TSC0OCUR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0TSC0OCUR</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCCO\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCPG\x22><ATTRIBUTES><ATTRIBUTE name=\x220TSC0OCPL\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0TSC0OCPL</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220TSC0OCPP\x22><ATTRIBUTES><ATTRIBUTE name=\x220TSC0OCPG\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220TSC0OCPL\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220TSC0OCUR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE><ATTRIBUTE name=\x220TSC0OKPR\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS><PRESENTATION>DISPLAY_KEY</PRESENTATION></PRESENTATIONS></RESULT_SET></ATTRIBUTE></ATTRIBUTES><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><ATTRIBUTES><ATTRIBUTE>0TSC0OCPG</ATTRIBUTE><ATTRIBUTE>0TSC0OCPL</ATTRIBUTE><ATTRIBUTE>0TSC0OCUR</ATTRIBUTE><ATTRIBUTE>0TSC0OKPR</ATTRIBUTE></ATTRIBUTES><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><RESULT_VISIBILITY>CONDITIONAL</RESULT_VISIBILITY><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><ATTRIBUTES/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC><CHARACTERISTIC name=\x220MEASURES0000000000000009\x22><MEMBER_ACCESS><PRESENTATIONS><PRESENTATION>TEXT</PRESENTATION></PRESENTATIONS><SORTING type=\x22DEFAULT\x22/></MEMBER_ACCESS><RESULT_SET><PRESENTATIONS binding=\x22MEMBER_ACCESS\x22/><SORTING type=\x22DEFAULT\x22/></RESULT_SET></CHARACTERISTIC></CHARACTERISTICS><AXES><AXIS name=\x22COLUMNS\x22><HIERARCHY><DRILL_LEVEL>00</DRILL_LEVEL></HIERARCHY><ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS>true</ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS><CHARACTERISTICS><CHARACTERISTIC>0MEASURES0000000000000009</CHARACTERISTIC></CHARACTERISTICS></AXIS><AXIS name=\x22ROWS\x22><HIERARCHY><DRILL_LEVEL>00</DRILL_LEVEL></HIERARCHY><ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS>true</ZERO_SUPPRESSION_ON_DATA_ENTRY_ENABLED_DATA_CELLS><CHARACTERISTICS/></AXIS></AXES><DATA_CELLS><DATA_CELL><MEMBERS><MEMBER name=\x220TSC0OKAC0000000000000009\x22 characteristic=\x220MEASURES0000000000000009\x22/></MEMBERS><APPLY_DETAIL_CALCULATION_TO_RESULTS>true</APPLY_DETAIL_CALCULATION_TO_RESULTS></DATA_CELL></DATA_CELLS><DRILL_OPERATIONS/><CONDITIONS/><EXCEPTIONS/></BICS_VIEW>'::BLOB, DESIGNTIME_INFO := STRUCT_PACK(QUERY_NAME := '', SELECTION_SPACE := LIST_VALUE(), SELECTION_STATE := LIST_VALUE(), VARIABLES := LIST_VALUE(), VARIABLE_CHARACTERISTICS_META := LIST_VALUE(), VARIABLE_CHARACTERISTICS_STATE := LIST_VALUE(), KEY_FIGURES := LIST_VALUE(), NODE_TYPES := LIST_VALUE(), HIERARCHIES := LIST_VALUE(), CHARACTERISTICS := LIST_VALUE(), SELECTION_STATE_SORTING := LIST_VALUE(), DATACELL_DETAILS := LIST_VALUE()), DIMENSIONS := LIST_VALUE(STRUCT_PACK(NAME := 'ZADEMP', TEXT := 'Data Package'), STRUCT_PACK(NAME := 'ZADEMT', TEXT := 'Time'), STRUCT_PACK(NAME := 'ZADEM1', TEXT := 'Organization'), STRUCT_PACK(NAME := 'ZADEM2', TEXT := 'Product'))) as X;")).fetchall()
result
# Out:
# [({'CHARACTERISTICS': [{'NAME': '0TSC0OCPP', 'ALTERNATIVE_NAME': '', 'ID': 525, 'TEXT': 'Product', 'HAS_SHORT_TEXT': 'X', 'HAS_MEDIUM_TEXT': '', 'HAS_LO ... (53277 characters truncated) ... EMP', 'TEXT': 'Data Package'}, {'NAME': 'ZADEMT', 'TEXT': 'Time'}, {'NAME': 'ZADEM1', 'TEXT': 'Organization'}, {'NAME': 'ZADEM2', 'TEXT': 'Product'}]},)]

# %%
engine.connect(
